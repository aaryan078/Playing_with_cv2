# %%
import numpy as np
import cv2

# %%
photo1=cv2.imread('man_of_steel-1200x800.jpg')

# %%
photo2=cv2.imread('the-witcher-season-2-netflix.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(photo1)
plt.show()

# %%
photo1[45:420,528:838]
# Out:
# array([[[108, 126, 209],
#         [108, 126, 209],
#         [108, 126, 209],
#         ...,
#         [108, 123, 196],
#         [108, 123, 196],
#         [108, 123, 196]],
#
#        [[107, 125, 208],
#         [107, 125, 208],
#         [107, 125, 208],
#         ...,
#         [108, 122, 198],
#         [109, 123, 199],
#         [109, 123, 199]],
#
#        [[107, 125, 208],
#         [107, 125, 208],
#         [107, 125, 208],
#         ...,
#         [109, 123, 199],
#         [110, 124, 200],
#         [110, 124, 200]],
#
#        ...,
#
#        [[224, 227, 231],
#         [224, 227, 231],
#         [224, 227, 231],
#         ...,
#         [224, 227, 232],
#         [223, 226, 231],
#         [223, 226, 231]],
#
#        [[224, 227, 231],
#         [224, 227, 231],
#         [224, 227, 231],
#         ...,
#         [224, 227, 232],
#         [223, 226, 231],
#         [223, 226, 231]],
#
#        [[224, 227, 231],
#         [224, 227, 231],
#         [224, 227, 231],
# ...

# %%
cv2.imshow("ss",photo1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
plt.imshow(photo2)
plt.show()

# %%
photo2[15:390,150:460]
# Out:
# array([[[52, 35, 14],
#         [53, 34, 13],
#         [52, 33, 12],
#         ...,
#         [59, 38, 17],
#         [62, 45, 24],
#         [62, 41, 20]],
#
#        [[52, 35, 16],
#         [51, 32, 11],
#         [47, 30,  9],
#         ...,
#         [60, 43, 22],
#         [59, 38, 17],
#         [59, 40, 19]],
#
#        [[48, 29,  8],
#         [52, 33, 12],
#         [52, 35, 16],
#         ...,
#         [64, 45, 24],
#         [58, 37, 16],
#         [60, 39, 18]],
#
#        ...,
#
#        [[70, 49, 28],
#         [72, 51, 30],
#         [72, 51, 30],
#         ...,
#         [77, 60, 41],
#         [82, 61, 39],
#         [84, 64, 47]],
#
#        [[68, 44, 24],
#         [59, 38, 17],
#         [73, 53, 28],
#         ...,
#         [79, 56, 34],
#         [66, 44, 26],
#         [75, 52, 30]],
#
#        [[60, 39, 18],
#         [66, 45, 24],
#         [66, 45, 24],
#         ...,
#         [64, 45, 24],
#         [74, 54, 29],
#         [84, 66, 43]]], dtype=uint8)

# %% [markdown]
# # crop photo swap

# %%
photo2[15:390,150:460],photo1[45:420,528:838]=photo1[45:420,528:838],photo2[15:390,150:460]

# %%
cv2.imshow("ss",photo2)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
photo1.shape
# Out:
# (800, 1200, 3)

# %%
f=photo1[20:250,120:300]
e=photo2[40:270,250:430]

# %%
f.shape
e.shape
# Out:
# (230, 180, 3)

# %%
f.shape
# Out:
# (230, 180, 3)

# %%
e.shape
# Out:
# (230, 180, 3)
